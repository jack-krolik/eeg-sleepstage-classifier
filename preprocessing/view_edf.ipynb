# %%
# script to view contents of edf files

import mne

file_path = "./data/Attune Validation_AttVal108_(1).edf"

raw = mne.io.read_raw_edf(file_path, preload=True)

print(raw.info)
# Out:
# Extracting EDF parameters from /home/jackkrolik/vscode/eeg-sleepstage-classifier/data/Attune Validation_AttVal108_(1).edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 8837887  =      0.000 ... 34522.996 secs...
# /tmp/ipykernel_537857/2025550916.py:7: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   raw = mne.io.read_raw_edf(file_path, preload=True)
# /tmp/ipykernel_537857/2025550916.py:7: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw = mne.io.read_raw_edf(file_path, preload=True)
# <Info | 8 non-empty values
#  bads: []
#  ch_names: E2:M1, E1:M2, F4:M1, F3:M2, C4:M1, C3:M2, P4:M1, P3:M2, O2:M1, ...
#  chs: 16 EEG
#  custom_ref_applied: False
#  highpass: 0.3 Hz
#  lowpass: 15.0 Hz
#  meas_date: 2024-07-12 22:26:45 UTC
#  nchan: 16
#  projs: []
#  sfreq: 256.0 Hz
#  subject_info: 6 items (dict)
# >

# %%
import pyedflib

# Load the EDF file
edf_file_path = './data/Attune Validation_AttVal108_(1).edf'  # Replace with the path to your EDF file
edf_reader = pyedflib.EdfReader(edf_file_path)

# Display general file information
print("File information:")
print(f"File Duration: {edf_reader.file_duration} seconds")
print(f"Number of Signals: {edf_reader.signals_in_file}")
print(f"Start Date/Time: {edf_reader.getStartdatetime()}")

# Get header information of each signal
print("\nSignal information:")
for i in range(edf_reader.signals_in_file):
    label = edf_reader.getLabel(i)
    physical_min = edf_reader.getPhysicalMinimum(i)
    physical_max = edf_reader.getPhysicalMaximum(i)
    digital_min = edf_reader.getDigitalMinimum(i)
    digital_max = edf_reader.getDigitalMaximum(i)
    transducer = edf_reader.getTransducer(i)
    prefilter = edf_reader.getPrefilter(i)
    sample_frequency = edf_reader.getSampleFrequency(i)
    
    print(f"\nSignal {i+1}:")
    print(f"  Label: {label}")
    print(f"  Physical Min: {physical_min}")
    print(f"  Physical Max: {physical_max}")
    print(f"  Digital Min: {digital_min}")
    print(f"  Digital Max: {digital_max}")
    print(f"  Transducer: {transducer}")
    print(f"  Prefilter: {prefilter}")
    print(f"  Sample Frequency: {sample_frequency}")

# Close the file after reading
edf_reader.close()
# Out:
# File information:
# File Duration: 34523.0 seconds
# Number of Signals: 16
# Start Date/Time: 2024-07-12 22:26:45
#
# Signal information:
#
# Signal 1:
#   Label: E2:M1
#   Physical Min: -1465.0
#   Physical Max: 1465.0
#   Digital Min: -32768
#   Digital Max: 32767
#   Transducer:
#   Prefilter:
#   Sample Frequency: 256.0
#
# Signal 2:
#   Label: E1:M2
#   Physical Min: -1465.0
#   Physical Max: 1465.0
#   Digital Min: -32768
#   Digital Max: 32767
#   Transducer:
#   Prefilter:
#   Sample Frequency: 256.0
#
# Signal 3:
#   Label: F4:M1
#   Physical Min: -1465.0
#   Physical Max: 1465.0
#   Digital Min: -32768
#   Digital Max: 32767
#   Transducer:
#   Prefilter:
#   Sample Frequency: 256.0
#
# Signal 4:
#   Label: F3:M2
#   Physical Min: -1465.0
#   Physical Max: 1465.0
#   Digital Min: -32768
#   Digital Max: 32767
#   Transducer:
#   Prefilter:
#   Sample Frequency: 256.0
#
# Signal 5:
#   Label: C4:M1
#   Physical Min: -1465.0
#   Physical Max: 1465.0
#   Digital Min: -32768
#   Digital Max: 32767
#   Transducer:
#   Prefilter:
#   Sample Frequency: 256.0
#
# Signal 6:
#   Label: C3:M2
#   Physical Min: -1465.0
#   Physical Max: 1465.0
#   Digital Min: -32768
#   Digital Max: 32767
#   Transducer:
#   Prefilter:
#   Sample Frequency: 256.0
#
# Signal 7:
#   Label: P4:M1
#   Physical Min: -1465.0
#   Physical Max: 1465.0
#   Digital Min: -32768
#   Digital Max: 32767
#   Transducer:
#   Prefilter:
#   Sample Frequency: 256.0
#
# Signal 8:
#   Label: P3:M2
#   Physical Min: -1465.0
#   Physical Max: 1465.0
#   Digital Min: -32768
#   Digital Max: 32767
#   Transducer:
#   Prefilter:
#   Sample Frequency: 256.0
#
# Signal 9:
#   Label: O2:M1
#   Physical Min: -1465.0
#   Physical Max: 1465.0
#   Digital Min: -32768
#   Digital Max: 32767
#   Transducer:
#   Prefilter:
#   Sample Frequency: 256.0
#
# Signal 10:
#   Label: O1:M2
#   Physical Min: -1465.0
#   Physical Max: 1465.0
#   Digital Min: -32768
#   Digital Max: 32767
#   Transducer:
#   Prefilter:
#   Sample Frequency: 256.0
#
# Signal 11:
#   Label: EMG1
#   Physical Min: -1465.0
#   Physical Max: 1465.0
#   Digital Min: -32768
#   Digital Max: 32767
#   Transducer:
#   Prefilter: HP:0.3Hz LP:110.0Hz
#   Sample Frequency: 256.0
#
# Signal 12:
#   Label: Pos.
#   Physical Min: 0.0
#   Physical Max: 10.0
#   Digital Min: 0
#   Digital Max: 10
#   Transducer:
#   Prefilter:
#   Sample Frequency: 4.0
#
# Signal 13:
#   Label: RIP Thora
#   Physical Min: -1000.0
#   Physical Max: 1000.0
#   Digital Min: -32768
#   Digital Max: 32767
#   Transducer:
#   Prefilter: HP:0.1Hz LP:15.0Hz
#   Sample Frequency: 32.0
#
# Signal 14:
#   Label: RIP Abdom
#   Physical Min: -1000.0
#   Physical Max: 1000.0
#   Digital Min: -32768
#   Digital Max: 32767
#   Transducer:
#   Prefilter: HP:0.1Hz LP:15.0Hz
#   Sample Frequency: 32.0
#
# Signal 15:
#   Label: Pulse
#   Physical Min: 0.0
#   Physical Max: 255.0
#   Digital Min: 0
#   Digital Max: 255
#   Transducer:
#   Prefilter:
#   Sample Frequency: 4.0
#
# Signal 16:
#   Label: SpO2
#   Physical Min: 0.0
#   Physical Max: 255.0
#   Digital Min: 0
#   Digital Max: 255
#   Transducer:
#   Prefilter:
#   Sample Frequency: 4.0
